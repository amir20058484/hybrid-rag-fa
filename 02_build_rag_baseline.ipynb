# %% [markdown]
# <div dir="rtl">
#
# # ۲ – ساخت RAG ساده روی اخبار فارسی
#
# در این نوت‌بوک، زیرمجموعه‌ی داده‌ی آماده‌شده را به چند بخش کوچک (چانک) تبدیل می‌کنید، برای هر چانک بردارهای embedding می‌سازید، یک ایندکس برداری (مثلاً با FAISS) ایجاد می‌کنید و در نهایت یک سیستم RAG ساده برای پاسخ‌گویی به سؤال‌های فارسی پیاده‌سازی می‌کنید.
#
# </div>

# %%
import pandas as pd
import os
import re
import pickle
import numpy as np
import pandas as pd
import faiss
from sentence_transformers import SentenceTransformer
from sklearn.preprocessing import normalize
from rank_bm25 import BM25Okapi

# %%
df = pd.read_csv("../data/processed/news_subset.csv")

print(df.head())

print("shape:", df.shape)
print("columns:", df.columns.tolist())
# Out:
#        id                                              title  \
# 0    7910  پرداخت 10 میلیارد ریال تسهیلات گردشگری در زنجا...
# 1  144943  حضور 3500 نفر در اردوهای هفت اقلیم در استان مرکزی
# 2  229417  آموزش سلامت دوران بلوغ در مدارس عشایر اصفهان ب...
# 3  149383  کیفیت فعلی هوای مشهد ناسالم است/ سال جاری برای...
# 4  103531  12 هزار و 920 همسر شهید یا جانباز در زنجان زند...
#
#                   short_link  service     subgroup  \
# 0       http://fna.ir/f1x73c  استانها        زنجان
# 1        http://fna.ir/491pa  استانها        مرکزی
# 2  http://mehrnews.com/xZV7j  استانها       اصفهان
# 3        http://fna.ir/4b6gc  استانها  خراسان رضوی
# 4        http://fna.ir/2iolx  استانها        زنجان
#
#                                             abstract  \
# 0  مدیرکل میراث فرهنگی، صنایع دستی و گردشگری استا...
# 1  فرمانده سپاه روح الله استان مرکزی گفت: از ابتد...
# 2  اصفهان-مشاور امور بانوان مدیرکل آموزش و پرورش ...
# 3  شاخص کیفیت هوای مشهد طی ۲۴ ساعت گذشته بر روی ع...
# 4  مسوول کمیته زنان کنگره ملی تجلیل از 3 هزار و 5...
#
#                                                 body  \
# 0  امیر ارجمند امروز در گفت وگو با خبرنگار فارس د...
# 1  به گزارش خبرگزاری فارس از اراک سردار سرتیپ دوم...
# 2  به گزارش خبرگزاری مهر، مرجان پناهی از تهیه بست...
# 3  به گزارش خبرگزاری فارس از مشهد، بر اساس داده ه...
# 4  به گزارش خبرگزاری فارس در زنجان، ماهرخ بلوری ع...
#
#                                                 tags      published_datetime  \
# 0  میراث فرهنگی, گردشگری, استان زنجان, صنایع دستی...     2021-01-13 06:38:00
# 1  امام خمینی, استان مرکزی, اردوهای هفت اقلیم, فر...     2021-10-06 04:04:03
# 2  اداره کل آموزش و پرورش اصفهان, مدارس عشایری, ب...  04/12/2023 10:39:00 AM
# 3  کیفیت  هوای مشهد, آلودگی هوای مشهد, وضعیت هواش...     2021-10-16 08:25:01
# 4  ماهرخ بلوری, مسؤول کمیته زنان کنگره ملی تجلیل ...     2021-07-14 09:08:32
#
#   agency_name
# 0    FarsNews
# 1    FarsNews
# 2    MehrNews
# 3    FarsNews
# 4    FarsNews
# shape: (10000, 10)
# columns: ['id', 'title', 'short_link', 'service', 'subgroup', 'abstract', 'body', 'tags', 'published_datetime', 'agency_name']

# %%
def chunk_text(text: str, chunk_size: int = 800, overlap: int = 150):
    text = ("" if text is None else str(text)).strip()
    step = chunk_size - overlap
    return [text[i:i + chunk_size] for i in range(0, len(text), step) if text[i:i + chunk_size].strip()]

df = pd.read_csv("../data/processed/news_subset.csv")

for col in ["title", "abstract", "body"]:
    df[col] = df[col].fillna("").astype(str).str.strip()

df["text_for_chunk"] = (
    "عنوان: " + df["title"] + "\n"
    "خلاصه: " + df["abstract"] + "\n"
    "متن: " + df["body"]
).str.strip()

rows = []
for _, r in df.iterrows():
    doc_id = r["id"]
    category = r["service"] if pd.notna(r["service"]) else r["subgroup"]
    date = r["published_datetime"]
    chunks = chunk_text(r["text_for_chunk"], 800, 150)
    for i, ch in enumerate(chunks):
        rows.append({"chunk_id": f"{doc_id}_{i}", "doc_id": doc_id, "text": ch, "category": category, "date": date})

chunks_df = pd.DataFrame(rows, columns=["chunk_id", "doc_id", "text", "category", "date"])
print(chunks_df.shape)
print(chunks_df.head(5))
# Out:
# (49959, 5)
#    chunk_id  doc_id                                               text  \
# 0    7910_0    7910  عنوان: پرداخت 10 میلیارد ریال تسهیلات گردشگری ...
# 1    7910_1    7910  ر آسیب شده اند، تمدید شده است. وی با اشاره به ...
# 2    7910_2    7910  افزود: به همین علت موزه های استان زنجان دوباره...
# 3    7910_3    7910   و واحدهای پذیرایی بین راهی با رعایت پروتکل ها...
# 4  144943_0  144943  عنوان: حضور 3500 نفر در اردوهای هفت اقلیم در ا...
#
#   category                 date
# 0  استانها  2021-01-13 06:38:00
# 1  استانها  2021-01-13 06:38:00
# 2  استانها  2021-01-13 06:38:00
# 3  استانها  2021-01-13 06:38:00
# 4  استانها  2021-10-06 04:04:03

# %%
out_dir = "artifacts"
os.makedirs(out_dir, exist_ok=True)

meta_cols = [c for c in ["chunk_id", "text", "category", "date"] if c in chunks_df.columns]
meta = chunks_df[meta_cols].copy()
meta.to_csv(os.path.join(out_dir, "chunks_meta.csv"), index=False, encoding="utf-8-sig")

texts = meta["text"].astype(str).tolist()

def tokenize_fa(s: str):
    s = "" if s is None else str(s)
    s = s.lower()
    s = re.sub(r"[^\w\u0600-\u06FF]+", " ", s)
    toks = [t for t in s.split() if t]
    return toks

semantic_model_name = "paraphrase-multilingual-MiniLM-L12-v2"
semantic_model = SentenceTransformer(semantic_model_name)

sem = semantic_model.encode(texts, batch_size=64, show_progress_bar=True, convert_to_numpy=True).astype(np.float32)
sem = normalize(sem, norm="l2").astype(np.float32)

index_sem = faiss.IndexFlatIP(sem.shape[1])
index_sem.add(sem)
faiss.write_index(index_sem, os.path.join(out_dir, "faiss_sem.index"))

corpus_tokens = [tokenize_fa(t) for t in texts]
bm25 = BM25Okapi(corpus_tokens)
with open(os.path.join(out_dir, "bm25.pkl"), "wb") as f:
    pickle.dump(bm25, f)

with open(os.path.join(out_dir, "config.pkl"), "wb") as f:
    pickle.dump({"semantic_model": semantic_model_name}, f)

print("saved:", os.path.abspath(out_dir))
print("faiss_sem.index ntotal:", index_sem.ntotal)
print("bm25 docs:", len(corpus_tokens))

meta_loaded = pd.read_csv(os.path.join(out_dir, "chunks_meta.csv"))
index_sem_loaded = faiss.read_index(os.path.join(out_dir, "faiss_sem.index"))
with open(os.path.join(out_dir, "bm25.pkl"), "rb") as f:
    bm25_loaded = pickle.load(f)
with open(os.path.join(out_dir, "config.pkl"), "rb") as f:
    cfg = pickle.load(f)
semantic_model_loaded = SentenceTransformer(cfg["semantic_model"])

def _semantic_search(question, top_k):
    q = semantic_model_loaded.encode([question], convert_to_numpy=True).astype(np.float32)
    q = normalize(q, norm="l2").astype(np.float32)
    scores, idxs = index_sem_loaded.search(q, top_k)
    return idxs[0].tolist(), scores[0].tolist()

def _bm25_search(question, top_k):
    q_tokens = tokenize_fa(question)
    scores = np.asarray(bm25_loaded.get_scores(q_tokens), dtype=np.float32)
    if top_k >= len(scores):
        top_idx = np.argsort(-scores)
    else:
        top_idx = np.argpartition(scores, -top_k)[-top_k:]
        top_idx = top_idx[np.argsort(-scores[top_idx])]
    return top_idx.tolist(), scores[top_idx].tolist()
# Out:
# Batches: 100%|██████████| 781/781 [11:02<00:00,  1.18it/s]
# saved: d:\Programming\Bootcamp\دوره ها\RAG2\rag-persian-news-lite-main\notebooks\artifacts
# faiss_sem.index ntotal: 49959
# bm25 docs: 49959

# %%
index = faiss.read_index("artifacts/faiss_sem.index")

D = index.d
ntotal = index.ntotal
print("D:", D, "| ntotal:", ntotal)

q = np.random.rand(1, D).astype(np.float32)
q /= (np.linalg.norm(q, axis=1, keepdims=True) + 1e-12)

scores, idxs = index.search(q, 5)
print("idxs:", idxs[0].tolist())
print("scores:", scores[0].tolist())
# Out:
# D: 384 | ntotal: 49959
# idxs: [6257, 7649, 24502, 20634, 40390]
# scores: [0.06989748775959015, 0.06839863955974579, 0.06826449930667877, 0.06683947890996933, 0.0666075199842453]

# %%
def retrieve(question, top_k=5, embedding_model="semantic", fusion_k=60, pool_mult=20):
    if embedding_model == "semantic":
        idxs, _ = _semantic_search(question, top_k)
        return meta_loaded.iloc[idxs]["text"].tolist()

    if embedding_model == "bm25":
        idxs, _ = _bm25_search(question, top_k)
        return meta_loaded.iloc[idxs]["text"].tolist()

    if embedding_model == "combined":
        pool_k = min(len(meta_loaded), top_k * pool_mult)
        sem_idxs, _ = _semantic_search(question, pool_k)
        bm_idxs, _ = _bm25_search(question, pool_k)

        fused = {}
        for r, i in enumerate(sem_idxs, start=1):
            fused[i] = fused.get(i, 0.0) + 1.0 / (fusion_k + r)
        for r, i in enumerate(bm_idxs, start=1):
            fused[i] = fused.get(i, 0.0) + 1.0 / (fusion_k + r)

        best = sorted(fused.items(), key=lambda x: x[1], reverse=True)[:top_k]
        idxs = [i for i, _ in best]
        return meta_loaded.iloc[idxs]["text"].tolist()

    raise ValueError("embedding_model باید یکی از این‌ها باشد: 'semantic' یا 'bm25' یا 'combined'")

# %%
def answer(question, top_k=5, embedding_model="semantic"):
    chunks = retrieve(question, top_k=top_k, embedding_model=embedding_model)
    return "\n\n".join(chunks)

# %%
questions = [
    "آخرین خبر درباره قیمت دلار چیست؟",
    "در مورد مذاکرات هسته‌ای چه خبرهایی منتشر شده؟",
]

for q in questions:
    print("Q:", q)

    print("\n--- semantic ---")
    print(answer(q, top_k=5, embedding_model="semantic"))

    print("\n--- bm25 ---")
    print(answer(q, top_k=5, embedding_model="bm25"))

    print("\n--- combined ---")
    print(answer(q, top_k=5, embedding_model="combined"))

    print("\n" + "="*70 + "\n")
# Out:
# Q: آخرین خبر درباره قیمت دلار چیست؟
#
# --- semantic ---
# عنوان: صندوق بین المللی پول: روند کنار گذاشتن دلار آغاز شده است
# خلاصه: رئیس صندوق بین المللی پول می گوید که روند فاصله گرفتن از دلار آمریکا هم اکنون در جریان است اما هنوز جایگزینی برای اسکناس سبز آمریکا وجود ندارد.
# متن: به گزارش خبرگزاری مهر به نقل از اسپوتنیک، کریستینا جورجیوا، مدیر اجرایی صندوق بین المللی پول بر این باور است که فاصله گرفتن از دلار آمریکا به عنوان ذخیره ارزی جهان در حال وقوع است اما به گفته وی در آینده نزدیک جایگزینی برای این ارز وجود ندارد. جورجیوا درباره این مساله گفت: دلیل نقش آفرینی دلار، قدرت اقتصاد آمریکا و عمق بازارهای سرمایه در این کشور است. وی افزود: و اگر در فکر گزینه جایگزین هستید، آن هم در دنیایی که احتمالا به طور گسترده به سمت ارزهای دیجیتال بانک مرکزی کشورها حرکت می کند، شاید گزینه های متفاوتی روی میز باشد اما در نهایت، قدرت اقتصاد آمریکا، عمق بازار سرمایه و
#
#  شد و ما شاهد جنگ اقتصادی غرب به رهبری آمریکا علیه کشورمان بودیم قیمت دلار بسیار بالاتر از 5 هزار تومان بود. وی افزود: در پایان دولت دهم قیمت دلار حدود ۳۵۰۰ تومان بود و در طول زمان کار دولت یازدهم و دوازدهم، نه تنها هیچگاه شاهد کاهش و توقف قیمت دلار نبودیم بلکه همواره شاهد افزایش قیمت آن بودیم. عضو هیئت رئیسه مجلس اظهار داشت: نه تنها زمانی که آمریکا از برجام خارج شد، بلکه زمانی هم که برجام به امضا رسید و طرف های اروپایی و آمریکا همگی در برجام بودند هیچ وقت روند افزایشی قیمت دلار متوقف نشد. موسوی خاطرنشان کرد: واقعیت این است که آقای رئیس جمهور با این اظهارات می خواهد بر ناکارآمدی و بی برنامگی دولتش سرپوش بگذارد، وگرنه اگر به امورات کشور در دولت های یازدهم و دوازدهم توجه داشته باشیم متوجه می شویم که بیشتر مشکلات و به هم ریختگی اقتصادی در کشور ما ناشی از بی برنامگی دولت است. وی افزود: آمریکا
#
# عنوان: پای مجلس بر گلوی ارز فسادزای ۴۲۰۰ تومانی
# خلاصه: از همان آغازی که دولت تصمیم به ارایه دلار با نرخ ۴۲۰۰ تومان برای به اصطلاح تهیه کالاهای اساسی گرفت، عموم کارشناسان در مورد رانت ویژه ای که از این ناحیه به وجود خواهد آمد، هشدار دادند و خواستار انصراف دولت از این تصمیم شدند.
# امی، قیمت را تا حدودی کنترل کند و به زیر 35 هزار تومان برساند اما باز هم این نرخ از قیمت مصوب گران تر بود. اسحاق جهانگیری معاون اول دولت هم با حضور در جلسه تامین کالاهای اساسی با تشکر از بانک مرکزی برای تامین ۱۰ میلیارد دلار ارز برای کالاهای اساسی در سال ۱۳۹۹ گفت: برای ۶ ماه نخست سال آینده هم ۶ میلیارد دلار ارز ۴۲۰۰ تومانی برای تامین کالاهای اساسی مورد نیاز کشور اختصاص می یابد. ** سخنگوی دولت: برنامه ای برای گرانی کالاهای اساسی نداریم محمود واعظی رئیس دفتر رئیس جمهور در حاشیه جلسه پاپان سال هیئت دولت با بیان اینکه دولت تلاش در راستای استفاده از ارز ترجیحی برای کالاهای مورد نیاز روزمره مردم بوده است، گفت: بخشی از کالاها وارداتی و بخشی هم تولید داخل است؛ وزارت صمت و وزارت جهاد کشاورزی باید دقت بیشتری در توزیع کالاها داشته باشند تا دست واسطه ها قطع شود، بخشی از گرانی ها به دلیل وجود واسطه هاس
#
# ======================================================================
#
# Q: در مورد مذاکرات هسته‌ای چه خبرهایی منتشر شده؟
#
# --- semantic ---
# ونیستی در بیانیه ای در خصوص گفت وگوهای وی در واشنگتن اعلام کرد رئیس ستاد کل ارتش بر نواقص توافق هسته ای کنونی که به ایران امکان پیشرفت قابل توجه در زمینه سانتریفیوژها و همچنین افزایش قبل ملاحظه میزان و کیفیت مواد غنی شده در چند سال آینده را می دهد تاکید کرد و همچنین کمبود نظارت در زمینه اشاعه هسته ای را مورد تاکید قرار داد. رئیس ستاد کل ارتش رژیم صهیونیستی در حالی به تکاپو افتاده است تا به اقدامات رژیم صهیونیستی علیه ایران جامه عمل بپوشاند که دور ششم مذاکرات وین به منظور احیای برجام که روز شنبه ۲۲ خرداد ماه با برگزاری نشست کمیسیون مشترک برجام در وین آغاز شد، در حالی به پایان رسیده که «سید عباس عراقچی» معاون وزارت خارجه جمهوری اسلامی ایران گفته تهران بدون رسیدن به خواسته های کلیدی خودش قطعاً توافق نخواهد کرد. دولت «جو بایدن» که حمایت خود را از کابینه جدید رژیم صهیونیستی اعلام کرده، مدعی است
#
# ی اتمی آغاز شده است». در این پیام در خصوص محور اصلی جلسه شورای حکام آژانس نوشته شده است: «دستورکار آن شامل موضوعات ایمنی هسته ای، امنیت هسته ای، استفاده صلح آمیز از اتم، راستی آزمایی و نظارت در ایران، به کارگیری پادمان ها و سیاست های شخصی آژانس بین المللی انرژی اتمی می شود». از طرف دیگر، «میخائیل اولیانوف» نماینده روسیه در سازمان های بین المللی مستقر در «وین» نیز در پیامی که در صفحه توییتری خود منتشر کرد، در خصوص این نشست گفت: «جلسه ماه سپتامبر شورای حکام آژانس آغاز شده است. قالب این نشست به صورت ترکیبی (مجازی و حضوری) است اما اکثر اعضای شورای حکام و کارشناسان آن ها ترجیح می دهند به جای حضور مجازی، در سالن اجلاس حضور داشته باشند. در دوران همه گیری، چنین چیزی (برگزاری ترکیبی نشست) برای اولین بار است که رخ می دهد». جلسه فصلی شورای حکام آژانس در حالی برگزار شده است که «رافائل گروسی» مدیرکل آژ
#
# ین روزها در انتهای کار دولتی هستیم که در 8 سال گذشته وعده و وعید های گوناگونی مبنی بر چرخش همزمان چرخ اقتصادی و هسته ای داد لیکن امروز پس از 8 سال گرانی های گسترده در سفره مردم قرار گرفته است، امروز که مجددا مذاکرات هسته ای آغاز شده اعلام می کنیم از هر مذاکره ای که بتواند منافع ملی را تامین کند پسندیده است و مورد حمایت است اما عموم مردم حق دارند نگران باشند که مبادا مجدد عایدی مردم و کشور ازاین مذاکرات تقریبا هیچ شود. این نماینده مجلس بیان کرد: دولت باید توجه کند که نشستن پشت میز مذاکره امتیازی است که از قانون اقدام راهبردی مجلس بدست آمده است و باید از این فرصت برای تامین منافع ملی استفاده کند، لذا ساده لوحی های گذشته نباید تکرار شوند، دولت توجه کند که حتی قدم زدن با وزیر خارجه آمریکا و دلخوش بودن به امضای وی مشکلات اقتصادی مردم را حل نخواهد کرد کما اینکه در گذشته نکرد بلکه دقت در نوشتن تف
#
# ن ماتون» نماینده تیم مذاکره کننده اروپا حاضر در وین گفت: «ما در حال پیشرفت هستیم، اما مذاکرات جدی در جریان است و تعدادی از مسائل از جمله در مورد چگونگی اجرای مراحل باقی مانده است. اتحادیه اروپا به گفت وگو با همه شرکت کنندگان ادامه خواهد داد و به طور جداگانه با ایالات متحده برای یافتن راه هایی برای رسیدن به توافق نهایی در روزهای آینده گفت و گو خواهد کرد.» نماینده چین در مذاکرات وین نیز روز شنبه گفت که لغو تحریم ها کلید اصلی هرگونه توافق درباره برنامه هسته ای ایران است. وی که با پایگاه خبری «الشرق» صحبت می کرد، افزود: «تمامی طرف ها به ارائه راه حل ها پایبند بود اما برخی موضوعات سیاسی حل نشده همچنان باقی مانده است.» «میخائیل اولیانوف» نماینده روسیه در سازمان های بین المللی در وین اتریش نیز در پیامی در توییتر نوشت: «همه شرکت کنندگان بر عزم خود برای به نتیجه رساندن موفقیت آمیز مذاکرات تاکید کرد
#
# ب در طول سال های اخیر و به ویژه در دورانی که مذاکرات هسته ای ایران و ۵+۱ در جریان بود، در پنج مرحله به مقابله با طرح نفوذ دشمن پرداختند: مرحله اول: هشدار به خواص و عوام در مورد خوش بینی به آمریکایی ها مرحله دوم: منحصر نمودن مذاکرات صرفاً به موضوع هسته ای مرحله سوم: تعیین خطوط قرمز و مدیریت تحذیر از طریق اقناع مرحله چهارم: مطالبه پاسخ در برابر زیاده خواهی های دشمن توسط دستگاه دیپلماسی و تیم مذاکره کننده هسته ای مرحله پنجم: افشای طرح نفوذ آمریکا در این راستا، معظّم له در دیدار فرماندهان سپاه پاسداران انقلاب اسلامی در تاریخ ۲۵ شهریورماه ۱۳۹۴ با صراحت می فرمایند: " امروز نفوذ دشمن یکی از تهدیدهای بزرگ است برای این کشور؛ دنبال نفوذند... از همه مهم تر نفوذ سیاسی و نفوذ فرهنگی است. نفوذ سیاسی هم این است که در مراکز تصمیم گیری، و اگر نشد تصمیم سازی نفوذ بکنند. وقتی دستگاه های سیاسی و دستگاه های مد
#
# --- bm25 ---
# تاق مذاکرات طرف های مشخصی حضور دارند که در حال مذاکره هستند و مشخص است که آنها چه طرفی هستند. اما بیرون از اتاق مذاکرات، مشخص نیست که چه هویتی حضور دارند و آنها دارند چه کاری انجام می دهند. همان موجود تنش زایی که تاسیسات هسته ای ایران را در عملیاتی تروریستی و حملات تروریستی هدف قرار داده است، همان موجود در تلاشی جدی برای ایجاد موانع در برابر حصول پیشرفت در مذاکرات است. این موجود علاوه بر تلاش برای مسموم کردن فضای مذاکرات در خارج از اتاق مذاکرات، امیدوار هستند که بتوانند یک فضای غیرسازنده در داخل اتاق مذاکرات ایجاد کنند». مجری پرس تی وی سوال کرد: «اسرائیل طی سال های گذشته دانشمندان هسته ای ایران را کشت، آنها اقداماتی از قبیل حملات سایبری، تروریسم هسته ای، خرابکاری در تاسیسات هسته ای انجام داده اند. آیا در مذاکرات درباره اینها صحبت شد؟ برای اینکه ایالات متحده در این حملات با اسرائیل مشارکت د
#
#  و حتی مجلس ضمن ترسیم خطوط قرمز در مذاکرات برجام، قانون اقدام راهبردی برای لغو تحریم ها و صیانت از منافع ملت ایران را هم تصویب کرده است. نماینده شیراز در مجلس افزود: اگر خطوط قرمز در مذاکرات وین رعایت نشود مجلس به هیچ وجه توافقات سست و بی پایه و اساس را نپذیرفته و با آن برخورد قاطعی خواهد کرد. لذا دولت و تیم مذاکره کننده هسته ای باید بدانند تا برای مجلس محرز و مسلم نشود که چه تصمیماتی طرف های مذاکره کننده گرفته اند و چه عایدی برای ملت ایران در مذاکرات وین حاصل خواهد شد مذاکرات را به رسمیت نمی شناسد. عزیزی تصریح کرد: شورای عالی امنیت ملی ناظر بر مذاکرات هسته ای است و با توجه به مسائل مختلف و جوانب متعدد موضوع را پیگیری خواهد کرد. وی در پاسخ به این سوال که قرار است هجدهم اردیبهشت مذاکرات وین با حضور ظریف و یا عراقچی در کمیسیون امنیت ملی مورد بحث و بررسی قرار گیرد گفت: یکی از وظایف اساسی و اص
#
# : روحانی، جهانگیری، ظریف و آشنا باید درباره اظهارات اخیر و بویژه انتشار فایل صوتی پاسخگو باشند زیرا مجلس اجازه نخواهد داد عده ای با منافع کشور بازی کنند. نماینده ساوجبلاغ در مجلس گفت: با انتشار فایل صوی ظریف، تردید جدی در مورد صلاحیت تیم مذاکرات کننده هسته ای ایران بوجود آمده است؛ ضمن اینکه چه تضمینی وجود دارد که در مذاکرات زد و بندی صورت نگیرد. انتهای پیام/
#
#  چیست؟ همه بدانند در مذاکرات چه گذشته است به غیر از ملت ایران و بعد هم در عین حال شعار شفاف سازی بدهیم! چرا ما نمایندگان مجلس توجه نمی کنیم که در این مذاکرات چه گذشته است؟ چون درنهایت این است که تحریم هایی که قرار بوده به یکباره برداشته شود نه تنها برداشته نمی شود بلکه اضافه می شود بعد هم وقتی اضافه می شود دوباره سیگنال غلط به افکار عمومی داده می شود، یک دیوانه ای رئیس جمهور آمریکا شده و همه چیز را بهم زده است! زمان اوباما تحریم ها اضافه شده است، در حین مذاکرات آمریکایی ها اعلام کردند که اگر ما تحریم ها را برداریم طور دیگری و با بهانه دیگری می توانیم آنها را برقرار کنیم، گزارش هایی در در آمریکا منتشر شد که گفته شد این گزارش ها در ایران مصرف داخلی دارد. حضرت آقا فرمود گزارش های واقعی را منتشر کنید که مردم بدانند و این گزارش ها هرگز منتشر نشد و در اختیار افکار عمومی قرار نگرفت. * در سیاست خا
#
# فت و بار دیگر شروع به تیراندازی به سمت سربازان آمریکایی در عراق کرد.» مورفی این توییت را در واکنش به مخالفت های سیاستمداران مخالف برجام با گزارش هایی درباره تصمیم بایدن جهت معرفی «رابرت مالی» به عنوان نماینده آمریکا در امور ایران منتشر کرده است. پایگاه «جوئیش اینسایدر» چند روز پیش گزارش داد جو بایدن قصد دارد «رابرت مالی»، از مقام های دولت سابق آمریکا که در مذاکرات هسته ای با ایران هم نقش داشته را به عنوان نماینده ویژه دولت در امور ایران منصوب کند. در روزهای گذشته برخی از سیاستمدارانی که خواستار لغو توافق هسته ای برجام هستند با انتخاب احتمالی مالی برای این سمت مخالفت کرده اند. انتهای پیام/
#
# --- combined ---
# ب در طول سال های اخیر و به ویژه در دورانی که مذاکرات هسته ای ایران و ۵+۱ در جریان بود، در پنج مرحله به مقابله با طرح نفوذ دشمن پرداختند: مرحله اول: هشدار به خواص و عوام در مورد خوش بینی به آمریکایی ها مرحله دوم: منحصر نمودن مذاکرات صرفاً به موضوع هسته ای مرحله سوم: تعیین خطوط قرمز و مدیریت تحذیر از طریق اقناع مرحله چهارم: مطالبه پاسخ در برابر زیاده خواهی های دشمن توسط دستگاه دیپلماسی و تیم مذاکره کننده هسته ای مرحله پنجم: افشای طرح نفوذ آمریکا در این راستا، معظّم له در دیدار فرماندهان سپاه پاسداران انقلاب اسلامی در تاریخ ۲۵ شهریورماه ۱۳۹۴ با صراحت می فرمایند: " امروز نفوذ دشمن یکی از تهدیدهای بزرگ است برای این کشور؛ دنبال نفوذند... از همه مهم تر نفوذ سیاسی و نفوذ فرهنگی است. نفوذ سیاسی هم این است که در مراکز تصمیم گیری، و اگر نشد تصمیم سازی نفوذ بکنند. وقتی دستگاه های سیاسی و دستگاه های مد
#
# عنوان: بلومبرگ: تل آویو برای متوقف کردن مذاکرات هسته ای تلاش می کند
# خلاصه: یک وبگاه آمریکایی گزارش داد کابینه رژیم صهیونیستی در تلاش است تا با فشار آوردن به دولت آمریکا، واشنگتن را به توقف مذاکرات هسته ای با ایران مجاب کند.
# متن: به گزارش گروه بین الملل خبرگزاری فارس، وبگاه «بلومبرگ» امروز (دوشنبه) در گزارشی به قلم «پائول والاس» خبر داد «نفتالی بنت» نخست وزیر رژیم صهیونیستی در سفری که به واشنگتن دارد تلاش می کند تا «جو بایدن» را از احیای توافق هسته ای ایران منصرف کند. در حالی که مقام های آمریکایی مشغول بررسی گزینه های پیش روی خود برای احیای برجام بعد از نتیجه بخش نبودن مذاکرات چند ماهه با ایران هستند، اما بنت و تیم صهیونیست های همراه او سعی دارند با فشار بر مقام های دولت بایدن، واشنگتن را به توقف مذاکرات هسته ای با ایران مجاب کنند. بنت نیز روز گذشته (یکشنبه) در صفحه توئیتر خود مدعی شده بود:
#
#  تاریخ ۲۰ ژوئن ۲۰۲۱ داشته باشد. در یکی از پیش نویس های ۲۰ ژوئن که مربوط به تعهدات هسته ای ایران بود، اختلافات زیاید بین دو طرف بود و متن پیشنویس مربوط به تعهدات هسته ای پر از پرانتز (جای خالی) بود که نشاندهنده تفاوت رویکرد بین دو طرف بود. تغییراتی که توسط تیم ایرانی روی متن مربوط به تعهدات هسته ای اعمال شد کمتر از تفاوتها و اختلافاتی که در متن اولیه سند ۲۰ ژوئن وجود داشت. از ابتدای مذاکرات نهم نوامبر (دور جدید مذاکرات در وین در دولت آقای رئیسی) دیدارها و نشست های متعددی در سطوح فنی و کارشناسان ارشد سیاسی انجام شد تا درباره هر دو پیش نویس صحبت شود. طی رو.زهای گذشته نشست های زیادی درباره گروه کاری تعهدات هسته ای انجام شد تا اختلافات را شناسایی کند ...تا تعداد اختلافات را کاهش داده و کم کند. بر همین اساس، همچنان گفت و گوها بین دو طرف در جریان است تا مساله اختلافات را نهایی کنند تا وارد آن مرح
#
# ین روزها در انتهای کار دولتی هستیم که در 8 سال گذشته وعده و وعید های گوناگونی مبنی بر چرخش همزمان چرخ اقتصادی و هسته ای داد لیکن امروز پس از 8 سال گرانی های گسترده در سفره مردم قرار گرفته است، امروز که مجددا مذاکرات هسته ای آغاز شده اعلام می کنیم از هر مذاکره ای که بتواند منافع ملی را تامین کند پسندیده است و مورد حمایت است اما عموم مردم حق دارند نگران باشند که مبادا مجدد عایدی مردم و کشور ازاین مذاکرات تقریبا هیچ شود. این نماینده مجلس بیان کرد: دولت باید توجه کند که نشستن پشت میز مذاکره امتیازی است که از قانون اقدام راهبردی مجلس بدست آمده است و باید از این فرصت برای تامین منافع ملی استفاده کند، لذا ساده لوحی های گذشته نباید تکرار شوند، دولت توجه کند که حتی قدم زدن با وزیر خارجه آمریکا و دلخوش بودن به امضای وی مشکلات اقتصادی مردم را حل نخواهد کرد کما اینکه در گذشته نکرد بلکه دقت در نوشتن تف
#
# آمریکا به برجام است و تاکنون در این زمینه رایزنی هایی با طرف آمریکایی انجام داده است. یکی دیگر از موضوعات مورد بحث در این سفر بحث صادرات تسلیحات نظامی به تل آویو است. این گزارش افزود، دولت واشنگتن قصد دارد درباره برخی مسائل منطقه ای از جمله بازگشت آمریکا به توافق هسته ای ایران که تا کنون مذاکرات غیرمستقیمی میان طرفین در این باره صورت گرفته است تضمین بدهد. مقام های دولت بایدن اعلام کرده اند که قصد دارند آمریکا را به توافق هسته ای برجام بازگردانند. با وجود این، دولت جدید آمریکا هنوز سازوکار خود برای بازگشت به توافق هسته ای را مشخص نکرده است. اعضای تیم بایدن در اظهاراتی مبهم می گویند قصد دارند از بازگشت به برجام به عنوان مبنایی برای «قوی تر و طولانی تر کردن» توافق هسته ای استفاده کنند. انتهای پیام/ص
#
# ======================================================================
